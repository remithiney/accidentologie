# %%
import pandas as pd
import numpy as np

df_usagers = pd.read_csv('datas/usagers-2022.csv', sep = ';')
df_vehicules = pd.read_csv('datas/vehicules-2022.csv', sep = ';')
df_caracts = pd.read_csv('datas/carcteristiques-2022.csv', sep = ';')
df_lieux = pd.read_csv('datas/lieux-2022.csv', sep = ';')
# Out:
# C:\Users\remi\AppData\Local\Temp\ipykernel_17640\664948161.py:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_lieux = pd.read_csv('datas/lieux-2022.csv', sep = ';')

# %%
display(df_caracts.head())
display(df_lieux.head())
display(df_vehicules.head())
display(df_usagers.head())
# Out:
#     Accident_Id  jour  mois    an   hrmn  lum dep    com  agg  int  atm  col  \
# 0  202200000001    19    10  2022  16:15    1  26  26198    2    3    1    3
# 1  202200000002    20    10  2022  08:34    1  25  25204    2    3    1    3
# 2  202200000003    20    10  2022  17:15    1  22  22360    2    6    1    2
# 3  202200000004    20    10  2022  18:00    1  16  16102    2    3    8    6
# 4  202200000005    19    10  2022  11:45    1  13  13103    1    1    1    2
#
#                            adr            lat            long
# 0       TEIL(vieille route du)  44,5594200000    4,7257200000
# 1                      Miranda  46,9258100000    6,3462000000
# 2      ROND POINT DE BREZILLET  48,4931620000   -2,7604390000
# 3               LOHMEYER (RUE)  45,6926520000   -0,3262900000
# 4  ROUTE DE JEAN MOULIN-RN 538  43,6755790366    5,0927031775
#         Num_Acc  catr                         voie  v1   v2  circ nbv  vosp  \
# ...

# %%
#caracts
#com = dep + 3 chiffres

# %%
print('caracts')
print(df_caracts.isnull().sum())
print('lieux')
print(df_lieux.isnull().sum())
print('vehicules')
print(df_vehicules.isnull().sum())
print('usagers')
print(df_usagers.isnull().sum())
# Out:
# caracts
# Accident_Id       0
# jour              0
# mois              0
# an                0
# hrmn              0
# lum               0
# dep               0
# com               0
# agg               0
# int               0
# atm               0
# col               0
# adr            1233
# lat               0
# long              0
# dtype: int64
# lieux
# Num_Acc        0
# catr           0
# voie        4805
# v1             0
# v2         50047
# circ           0
# nbv            0
# vosp           0
# prof           0
# pr             0
# pr1            0
# plan           0
# lartpc     55274
# larrout        0
# surf           0
# infra          0
# situ           0
# vma            0
# dtype: int64
# vehicules
# Num_Acc            0
# id_vehicule        0
# num_veh            0
# senc               0
# catv               0
# obs                0
# obsm               0
# choc               0
# manv               0
# motor              0
# occutc         93676
# dtype: int64
# ...

# %%
print('caracts')
display(df_caracts.describe())
print('lieux')
display(df_lieux.describe())
print('vehicules')
display(df_vehicules.describe())
print('usagers')
display(df_usagers.describe())
# Out:
# caracts
#         Accident_Id          jour          mois       an           lum  \
# count  5.530200e+04  55302.000000  55302.000000  55302.0  55302.000000
# mean   2.022000e+11     15.607971      6.588514   2022.0      1.927308
# std    1.596446e+04      8.719319      3.332152      0.0      1.490073
# min    2.022000e+11      1.000000      1.000000   2022.0     -1.000000
# 25%    2.022000e+11      8.000000      4.000000   2022.0      1.000000
# 50%    2.022000e+11     15.000000      7.000000   2022.0      1.000000
# 75%    2.022000e+11     23.000000      9.000000   2022.0      3.000000
# max    2.022001e+11     31.000000     12.000000   2022.0      5.000000
#
#                 agg           int           atm           col
# count  55302.000000  55302.000000  55302.000000  55302.000000
# mean       1.633539      2.063705      1.587212      4.007522
# std        0.481842      1.983497      1.673828      1.980689
# min        1.000000     -1.000000     -1.000000     -1.000000
# ...

# %%
#caracts 
#int des -1 existent

#lieux
#vma 700 = valeur abérante

#usagers 
#grav = -1 à retirer ?

# %%
print('caracts')
display(df_caracts.info())
print('lieux')
display(df_lieux.info())
print('vehicules')
display(df_vehicules.info())
print('usagers')
display(df_usagers.info())
# Out:
# caracts
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55302 entries, 0 to 55301
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Accident_Id  55302 non-null  int64
#  1   jour         55302 non-null  int64
#  2   mois         55302 non-null  int64
#  3   an           55302 non-null  int64
#  4   hrmn         55302 non-null  object
#  5   lum          55302 non-null  int64
#  6   dep          55302 non-null  object
#  7   com          55302 non-null  object
#  8   agg          55302 non-null  int64
#  9   int          55302 non-null  int64
#  10  atm          55302 non-null  int64
#  11  col          55302 non-null  int64
#  12  adr          54069 non-null  object
#  13  lat          55302 non-null  object
#  14  long         55302 non-null  object
# dtypes: int64(9), object(6)
# memory usage: 6.3+ MB
# None
# lieux
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55302 entries, 0 to 55301
# ...

# %%
#nb caracts = nb lieux (ok) 
#nb usagers > vl (ok)

#types à déterminer
